# %% [markdown]
# Hello there

# %%
from pathlib import Path
import pandas as pd
import gzip, json

# The notebook's directory as the base
notebook_dir = Path('aqcuisition_fase-scrapers/Debatepolitics/ice+term-uitkeyword.jsonl.gz')


with gzip.open(notebook_dir, 'rt', encoding='utf-8') as f:
    objs = [json.loads(l) for l in f]
df = pd.json_normalize(objs)
# print panda's version
print(f"Pandas version: {pd.__version__}")
# Out:
# Pandas version: 3.0.0

# %% [markdown]
# ### Overzichtje van de data

# %%
df.info()
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   matched_terms    671 non-null    object
#  1   scraped_at_utc   671 non-null    str
#  2   page_title       671 non-null    str
#  3   thread_title     671 non-null    str
#  4   forum_path       671 non-null    str
#  5   source_page_url  671 non-null    str
#  6   post_url         671 non-null    str
#  7   post_id          669 non-null    str
#  8   author           29 non-null     str
#  9   datetime         671 non-null    str
#  10  quote_count      671 non-null    int64
#  11  snippet          671 non-null    str
#  12  text             671 non-null    str
# dtypes: int64(1), object(1), str(11)
# memory usage: 68.3+ KB
#      matched_terms                    scraped_at_utc  \
# 0   [ice shooting]  2026-02-07T14:49:27.364700+00:00
# ...

# %%
df.isnull().sum(),f"the file consists of this number of lines and colums {df.shape}"
# Out:
# (matched_terms        0
#  scraped_at_utc       0
#  page_title           0
#  thread_title         0
#  forum_path           0
#  source_page_url      0
#  post_url             0
#  post_id              2
#  author             642
#  datetime             0
#  quote_count          0
#  snippet              0
#  text                 0
#  dtype: int64,
#  'the file consists of this number of lines and colums (671, 13)')

# %% [markdown]
# ### Lets go cleaning

# %%
df1 = df.drop(columns=['author'])
df1 = df1.dropna(axis=0, subset=['post_id'])
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 669 entries, 0 to 670
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   matched_terms    669 non-null    object
#  1   scraped_at_utc   669 non-null    str
#  2   page_title       669 non-null    str
#  3   thread_title     669 non-null    str
#  4   forum_path       669 non-null    str
#  5   source_page_url  669 non-null    str
#  6   post_url         669 non-null    str
#  7   post_id          669 non-null    str
#  8   datetime         669 non-null    str
#  9   quote_count      669 non-null    int64
#  10  snippet          669 non-null    str
#  11  text             669 non-null    str
# dtypes: int64(1), object(1), str(10)
# memory usage: 67.9+ KB

# %%
# df1.to_json('analyse_fase-kenmerken_onderzoek/Sentiment/dp-set1-cleaned.jsonl.gz', orient='records', lines=True, compression='gzip')

# %%
df2 = pd.read_json('analyse_fase-kenmerken_onderzoek/Data/dp-set1-cleaned.jsonl.gz', orient='records', lines=True, compression='gzip')
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   matched_terms    669 non-null    object
#  1   scraped_at_utc   669 non-null    str
#  2   page_title       669 non-null    str
#  3   thread_title     669 non-null    str
#  4   forum_path       669 non-null    str
#  5   source_page_url  669 non-null    str
#  6   post_url         669 non-null    str
#  7   post_id          669 non-null    str
#  8   datetime         669 non-null    str
#  9   quote_count      669 non-null    int64
#  10  snippet          669 non-null    str
#  11  text             669 non-null    str
# dtypes: int64(1), object(1), str(10)
# memory usage: 62.8+ KB

# %%
df3 = pd.read_json('analyse_fase-kenmerken_onderzoek/Data/dp-set1-cleaned.jsonl.gz', orient='records', lines=True, compression='gzip')
df4 = pd.read_json('analyse_fase-kenmerken_onderzoek/Data/dp-set2-cleaned.jsonl.gz', orient='records', lines=True, compression='gzip')
# print(f"{df3.info()} en {df4.info()}")
pd.concat([df3.describe(include="all"), df4.describe(include="all")], keys=['df3', 'df4']) # probeersel om data van beide dataframes te vergelijken, maar het is niet echt duidelijk. 
#Misschien beter om gewoon de info() van beide dataframes te printen en te vergelijken?
# Out:
#             matched_terms                    scraped_at_utc  \
# df3 count             669                               669
#     unique             25                               626
#     top     [ice officer]  2026-02-08T08:14:46.811371+00:00
#     freq              192                                 5
#     mean              NaN                               NaN
#     std               NaN                               NaN
#     min               NaN                               NaN
#     25%               NaN                               NaN
#     50%               NaN                               NaN
#     75%               NaN                               NaN
#     max               NaN                               NaN
# df4 count             NaN                               NaN
#     unique            NaN                               NaN
#     top               NaN                               NaN
#     freq              NaN                               NaN
# ...

# %%
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   matched_terms    669 non-null    object
#  1   scraped_at_utc   669 non-null    str
#  2   page_title       669 non-null    str
#  3   thread_title     669 non-null    str
#  4   forum_path       669 non-null    str
#  5   source_page_url  669 non-null    str
#  6   post_url         669 non-null    str
#  7   post_id          669 non-null    str
#  8   datetime         669 non-null    str
#  9   quote_count      669 non-null    int64
#  10  snippet          669 non-null    str
#  11  text             669 non-null    str
# dtypes: int64(1), object(1), str(10)
# memory usage: 62.8+ KB

# %%
df4.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4586 entries, 0 to 4585
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   source           4586 non-null   str
#  1   scraped_at       4586 non-null   datetime64[us, UTC]
#  2   media            4586 non-null   object
#  3   keywords_hit     4586 non-null   object
#  4   thread.url       4586 non-null   str
#  5   thread.title     4586 non-null   str
#  6   thread.page_url  4586 non-null   str
#  7   thread.page_num  4586 non-null   int64
#  8   post.id          4586 non-null   int64
#  9   post.author      4586 non-null   str
#  10  post.created_at  4586 non-null   str
#  11  content.text     4586 non-null   str
#  12  content.html     4586 non-null   str
#  13  entities.links   4586 non-null   object
# dtypes: datetime64[us, UTC](1), int64(2), object(3), str(8)
# memory usage: 501.7+ KB
