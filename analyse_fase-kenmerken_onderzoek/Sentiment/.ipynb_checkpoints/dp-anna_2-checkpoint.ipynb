# %% [markdown]
# Hello there

# %%
from pathlib import Path
import pandas as pd
import gzip, json
notebook_dir = Path(r"C:\Users\marco\OneDrive\Desktop\radical\aqcuisition_fase-scrapers\Debatepolitics\data\debatepolitics\matches.jsonl.gz")

with gzip.open(notebook_dir, 'rt', encoding='utf-8') as f:
    objs = [json.loads(l) for l in f]
df = pd.json_normalize(objs)
df.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23124\2711229616.py in <module>
#       4 notebook_dir = Path(r"C:\Users\maro\OneDrive\Desktop\radical\aqcuisition_fase-scrapers\Debatepolitics\data\debatepolitics\matches.jsonl.gz")
#       5
# ----> 6 with gzip.open(notebook_dir, 'rt', encoding='utf-8') as f:
#       7     objs = [json.loads(l) for l in f]
#       8 df = pd.json_normalize(objs)
#
# ~\miniconda3\lib\gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      56     gz_mode = mode.replace("t", "")
#      57     if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 58         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      59     elif hasattr(filename, "read") or hasattr(filename, "write"):
#      60         binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# ...
