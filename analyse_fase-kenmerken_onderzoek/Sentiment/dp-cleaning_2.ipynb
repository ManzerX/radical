# %% [markdown]
# Hello there

# %%
from pathlib import Path
import pandas as pd
import gzip, json
notebook_dir = Path("aqcuisition_fase-scrapers/Debatepolitics/data/debatepolitics/matches.jsonl.gz")

with gzip.open(notebook_dir, 'rt', encoding='utf-8') as f:
    objs = [json.loads(l) for l in f]
df = pd.json_normalize(objs)
df.info()
# Out:
# Failed to connect to the remote Jupyter Server 'http://localhost:8888/'. Verify the server is running and reachable. (Failed to connect to the remote Jupyter Server 'http://localhost:8888/'. Verify the server is running and reachable. (Forbidden).).
