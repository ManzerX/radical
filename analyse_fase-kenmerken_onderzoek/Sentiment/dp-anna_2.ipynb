# %% [markdown]
# Hello there

# %%
from pathlib import Path
import pandas as pd
import gzip, json
notebook_dir = Path(r"aqcuisition_fase-scrapers\Debatepolitics\data\debatepolitics\matches.jsonl.gz")

with gzip.open(notebook_dir, 'rt', encoding='utf-8') as f:
    objs = [json.loads(l) for l in f]
df = pd.json_normalize(objs)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4586 entries, 0 to 4585
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   source            4586 non-null   object
#  1   scraped_at        4586 non-null   object
#  2   media             4586 non-null   object
#  3   keywords_hit      4586 non-null   object
#  4   thread.id         2899 non-null   float64
#  5   thread.url        4586 non-null   object
#  6   thread.title      4586 non-null   object
#  7   thread.forum_url  0 non-null      object
#  8   thread.page_url   4586 non-null   object
#  9   thread.page_num   4586 non-null   int64
#  10  post.id           4586 non-null   int64
#  11  post.author       4586 non-null   object
#  12  post.created_at   4586 non-null   object
#  13  content.text      4586 non-null   object
#  14  content.html      4586 non-null   object
#  15  entities.links    4586 non-null   object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 573.4+ KB
